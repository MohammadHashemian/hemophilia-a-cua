# %%
from __future__ import annotations

import numpy as np
import polars as pl

from app.domain.enums import HealthStates
from app.notebook.cache import resolve_cache
from app.persistence.context import ModelContext
from utils.logging import setup_root_logger
from utils.path_utils import get_project_root

# -----------------------------
# Notebook setup
# -----------------------------

logger = setup_root_logger()
root = get_project_root()
context = ModelContext.load()
path = resolve_cache("owsa", root=root)

df = pl.read_parquet(
    path=path,
    engine="auto",
    columns=[
        "scenario",
        "time_horizon",
        "regime",
        "extension",
        "sampling_method",
        "sampled_abr",
        "cycles",
        "observed_cycles",
        "person_years",
        "lost_person_years",
        "lost_person_year_life_expectancy",
        "total_factor",
        "total_qaly",
        "total_cost",
        "annual_cost",
        "pettersson_score",
        "absorbed_at",
        "is_absorbed",
        "bleeding_events",
        "spontaneous_bleeding_events",
        "joint_bleeding_events",
        "intracranial_hemorrhage_events",
        "non_ich_major_bleeding_events",
        "annual_bleeding_rate",
        "spontaneous_bleeding_rate",
        "annual_joint_bleeding_rate",
        "annual_intracranial_hemorrhage_rate",
        "annual_non_ich_major_bleeding_rate",
    ],
)
dropped_rows = [
    "early on_demand bayesian weight_low",
    "early prophylaxis bayesian weight_low",
    "lifetime on_demand bayesian weight_low",
    "lifetime prophylaxis bayesian weight_low",
    "early on_demand bayesian weight_high",
    "early prophylaxis bayesian weight_high",
    "lifetime on_demand bayesian weight_high",
    "lifetime prophylaxis bayesian weight_high",
]

df = df[~df["scenario"].isin(dropped_rows)]

regimes = df["regime"].unique()
scenarios = df["scenario"].unique()
states = [state.value for state in HealthStates]

logger.info("Data loaded successfully with %d rows", len(df))

# Compact inline rendering (150 dpi) - keep inline images sharp.
from app.notebook.plot_style import apply_inline_style

apply_inline_style()
# Out:
# [20:37:02] INFO     Data loaded successfully with 116000 rows

# %%
from app.notebook.scenario_helpers import pair_scenarios, parse_scenario

pairs = pair_scenarios(df["scenario"].unique().tolist())

for control, intervention in pairs:
    control_df = df.filter(pl.col("scenario") == control)
    intervention_df = df.filter(pl.col("scenario") == intervention)

    control_cost = control_df["total_cost"].mean()
    intervention_cost = intervention_df["total_cost"].mean()

    control_qaly = control_df["total_qaly"].mean()
    intervention_qaly = intervention_df["total_qaly"].mean()

    incremental_cost = intervention_cost - control_cost
    incremental_qaly = intervention_qaly - control_qaly

    print(f"\n{intervention} vs {control}")

    print(f"Intervention ABR: {intervention_df['sampled_abr'].mean():,.0f}")
    print(f"Control ABR: {control_df['sampled_abr'].mean():,.0f}")

    print(f"Intervention cost: {intervention_cost:,.0f} IRR")
    print(f"Control cost:      {control_cost:,.0f} IRR")

    print(f"Intervention QALY: {intervention_qaly:.2f}")
    print(f"Control QALY:      {control_qaly:.2f}")

    print(f"Incremental cost:  {incremental_cost:,.0f} IRR")
    print(f"Incremental QALY:  {incremental_qaly:.2f}")

    if incremental_cost < 0 and incremental_qaly > 0:
        print("Result: Intervention is dominant")
    elif incremental_cost > 0 and incremental_qaly < 0:
        print("Result: Intervention is dominated")
    elif incremental_qaly == 0:
        print("Result: ICER undefined (ΔQALY = 0)")
    else:
        icer = incremental_cost / incremental_qaly
        print(f"ICER: {icer:,.0f} IRR/QALY")
# Out:
# early prophylaxis bayesian vs early on_demand bayesian
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,267,270,442 IRR
# Control cost:      27,822,411,726 IRR
# Intervention QALY: 8.54
# Control QALY:      6.67
# Incremental cost:  47,444,858,716 IRR
# Incremental QALY:  1.87
# ICER: 25,366,630,960 IRR/QALY
#
# lifetime prophylaxis bayesian vs lifetime on_demand bayesian
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,309,384,644,618 IRR
# Control cost:      259,860,115,438 IRR
# Intervention QALY: 57.58
# Control QALY:      25.77
# Incremental cost:  1,049,524,529,180 IRR
# Incremental QALY:  31.81
# ICER: 32,992,807,974 IRR/QALY
#
# early prophylaxis bayesian abr_low vs early on_demand bayesian abr_low
# Intervention ABR: 2
# Control ABR: 5
# Intervention cost: 72,578,336,102 IRR
# Control cost:      7,071,924,595 IRR
# Intervention QALY: 8.76
# Control QALY:      8.33
# Incremental cost:  65,506,411,507 IRR
# Incremental QALY:  0.43
# ICER: 152,705,934,388 IRR/QALY
#
# lifetime prophylaxis bayesian abr_low vs lifetime on_demand bayesian abr_low
# Intervention ABR: 2
# Control ABR: 5
# Intervention cost: 1,360,649,754,262 IRR
# Control cost:      116,887,680,012 IRR
# Intervention QALY: 64.51
# Control QALY:      53.19
# Incremental cost:  1,243,762,074,249 IRR
# Incremental QALY:  11.33
# ICER: 109,819,439,086 IRR/QALY
#
# early prophylaxis bayesian abr_high vs early on_demand bayesian abr_high
# Intervention ABR: 8
# Control ABR: 68
# Intervention cost: 80,128,597,378 IRR
# Control cost:      57,231,236,448 IRR
# Intervention QALY: 8.08
# Control QALY:      4.54
# Incremental cost:  22,897,360,930 IRR
# Incremental QALY:  3.54
# ICER: 6,463,165,149 IRR/QALY
#
# lifetime prophylaxis bayesian abr_high vs lifetime on_demand bayesian abr_high
# Intervention ABR: 8
# Control ABR: 68
# Intervention cost: 1,136,729,693,957 IRR
# Control cost:      211,884,022,023 IRR
# Intervention QALY: 44.64
# Control QALY:      8.81
# Incremental cost:  924,845,671,934 IRR
# Incremental QALY:  35.82
# ICER: 25,816,908,576 IRR/QALY
#
# early prophylaxis bayesian joint_bleeding_fraction_low vs early on_demand bayesian joint_bleeding_fraction_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,570,099,610 IRR
# Control cost:      27,898,961,466 IRR
# Intervention QALY: 8.56
# Control QALY:      6.57
# Incremental cost:  47,671,138,144 IRR
# Incremental QALY:  1.98
# ICER: 24,022,593,043 IRR/QALY
#
# lifetime prophylaxis bayesian joint_bleeding_fraction_low vs lifetime on_demand bayesian joint_bleeding_fraction_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,273,001,054,961 IRR
# Control cost:      278,450,384,107 IRR
# Intervention QALY: 56.15
# Control QALY:      26.92
# Incremental cost:  994,550,670,854 IRR
# Incremental QALY:  29.23
# ICER: 34,022,731,923 IRR/QALY
#
# early prophylaxis bayesian joint_bleeding_fraction_high vs early on_demand bayesian joint_bleeding_fraction_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,510,249,652 IRR
# Control cost:      26,843,027,960 IRR
# Intervention QALY: 8.48
# Control QALY:      6.59
# Incremental cost:  47,667,221,691 IRR
# Incremental QALY:  1.89
# ICER: 25,156,104,765 IRR/QALY
#
# lifetime prophylaxis bayesian joint_bleeding_fraction_high vs lifetime on_demand bayesian joint_bleeding_fraction_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,290,273,396,917 IRR
# Control cost:      259,084,673,929 IRR
# Intervention QALY: 56.87
# Control QALY:      26.00
# Incremental cost:  1,031,188,722,989 IRR
# Incremental QALY:  30.87
# ICER: 33,403,156,836 IRR/QALY
#
# early prophylaxis bayesian life_threatening_bleeding_fraction_low vs early on_demand bayesian life_threatening_bleeding_fraction_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 76,473,823,864 IRR
# Control cost:      27,670,264,815 IRR
# Intervention QALY: 8.68
# Control QALY:      6.88
# Incremental cost:  48,803,559,048 IRR
# Incremental QALY:  1.80
# ICER: 27,185,976,403 IRR/QALY
#
# lifetime prophylaxis bayesian life_threatening_bleeding_fraction_low vs lifetime on_demand bayesian life_threatening_bleeding_fraction_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,390,911,817,827 IRR
# Control cost:      355,976,884,948 IRR
# Intervention QALY: 60.94
# Control QALY:      34.37
# Incremental cost:  1,034,934,932,879 IRR
# Incremental QALY:  26.57
# ICER: 38,949,604,196 IRR/QALY
#
# early prophylaxis bayesian life_threatening_bleeding_fraction_high vs early on_demand bayesian life_threatening_bleeding_fraction_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,092,585,741 IRR
# Control cost:      26,842,813,523 IRR
# Intervention QALY: 8.41
# Control QALY:      6.21
# Incremental cost:  47,249,772,219 IRR
# Incremental QALY:  2.19
# ICER: 21,551,451,051 IRR/QALY
#
# lifetime prophylaxis bayesian life_threatening_bleeding_fraction_high vs lifetime on_demand bayesian life_threatening_bleeding_fraction_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,103,589,184,442 IRR
# Control cost:      163,190,070,078 IRR
# Intervention QALY: 49.18
# Control QALY:      17.11
# Incremental cost:  940,399,114,363 IRR
# Incremental QALY:  32.07
# ICER: 29,321,181,872 IRR/QALY
#
# early prophylaxis bayesian healthy_utility_low vs early on_demand bayesian healthy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,321,366,892 IRR
# Control cost:      27,302,585,734 IRR
# Intervention QALY: 7.76
# Control QALY:      6.44
# Incremental cost:  47,018,781,158 IRR
# Incremental QALY:  1.32
# ICER: 35,715,363,566 IRR/QALY
#
# lifetime prophylaxis bayesian healthy_utility_low vs lifetime on_demand bayesian healthy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,233,111,742,872 IRR
# Control cost:      269,958,408,902 IRR
# Intervention QALY: 53.37
# Control QALY:      26.39
# Incremental cost:  963,153,333,970 IRR
# Incremental QALY:  26.98
# ICER: 35,694,816,605 IRR/QALY
#
# early prophylaxis bayesian healthy_utility_high vs early on_demand bayesian healthy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,638,393,590 IRR
# Control cost:      26,847,284,586 IRR
# Intervention QALY: 9.01
# Control QALY:      6.59
# Incremental cost:  47,791,109,004 IRR
# Incremental QALY:  2.42
# ICER: 19,726,282,889 IRR/QALY
#
# lifetime prophylaxis bayesian healthy_utility_high vs lifetime on_demand bayesian healthy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,245,249,173,485 IRR
# Control cost:      255,767,953,777 IRR
# Intervention QALY: 55.97
# Control QALY:      25.51
# Incremental cost:  989,481,219,708 IRR
# Incremental QALY:  30.46
# ICER: 32,486,078,889 IRR/QALY
#
# early prophylaxis bayesian mild_arthropathy_utility_low vs early on_demand bayesian mild_arthropathy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,635,168,744 IRR
# Control cost:      26,954,414,002 IRR
# Intervention QALY: 8.49
# Control QALY:      6.27
# Incremental cost:  47,680,754,741 IRR
# Incremental QALY:  2.23
# ICER: 21,413,957,043 IRR/QALY
#
# lifetime prophylaxis bayesian mild_arthropathy_utility_low vs lifetime on_demand bayesian mild_arthropathy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,265,762,517,075 IRR
# Control cost:      259,323,931,457 IRR
# Intervention QALY: 52.45
# Control QALY:      25.10
# Incremental cost:  1,006,438,585,618 IRR
# Incremental QALY:  27.36
# ICER: 36,785,960,022 IRR/QALY
#
# early prophylaxis bayesian mild_arthropathy_utility_high vs early on_demand bayesian mild_arthropathy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,205,938,282 IRR
# Control cost:      27,442,596,783 IRR
# Intervention QALY: 8.45
# Control QALY:      6.87
# Incremental cost:  46,763,341,499 IRR
# Incremental QALY:  1.58
# ICER: 29,591,485,372 IRR/QALY
#
# lifetime prophylaxis bayesian mild_arthropathy_utility_high vs lifetime on_demand bayesian mild_arthropathy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,259,116,730,752 IRR
# Control cost:      256,456,510,695 IRR
# Intervention QALY: 58.58
# Control QALY:      26.07
# Incremental cost:  1,002,660,220,057 IRR
# Incremental QALY:  32.51
# ICER: 30,846,166,746 IRR/QALY
#
# early prophylaxis bayesian moderate_arthropathy_utility_low vs early on_demand bayesian moderate_arthropathy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,726,819,796 IRR
# Control cost:      28,120,455,201 IRR
# Intervention QALY: 8.50
# Control QALY:      6.75
# Incremental cost:  46,606,364,594 IRR
# Incremental QALY:  1.75
# ICER: 26,602,130,393 IRR/QALY
#
# lifetime prophylaxis bayesian moderate_arthropathy_utility_low vs lifetime on_demand bayesian moderate_arthropathy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,226,093,918,751 IRR
# Control cost:      274,688,939,281 IRR
# Intervention QALY: 54.36
# Control QALY:      26.29
# Incremental cost:  951,404,979,470 IRR
# Incremental QALY:  28.06
# ICER: 33,902,143,980 IRR/QALY
#
# early prophylaxis bayesian moderate_arthropathy_utility_high vs early on_demand bayesian moderate_arthropathy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,254,849,467 IRR
# Control cost:      27,422,474,559 IRR
# Intervention QALY: 8.55
# Control QALY:      6.66
# Incremental cost:  47,832,374,908 IRR
# Incremental QALY:  1.88
# ICER: 25,395,959,983 IRR/QALY
#
# lifetime prophylaxis bayesian moderate_arthropathy_utility_high vs lifetime on_demand bayesian moderate_arthropathy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,288,939,275,346 IRR
# Control cost:      260,057,132,657 IRR
# Intervention QALY: 56.78
# Control QALY:      26.38
# Incremental cost:  1,028,882,142,690 IRR
# Incremental QALY:  30.40
# ICER: 33,845,051,968 IRR/QALY
#
# early prophylaxis bayesian severe_arthropathy_utility_low vs early on_demand bayesian severe_arthropathy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,951,559,593 IRR
# Control cost:      27,252,967,657 IRR
# Intervention QALY: 8.50
# Control QALY:      6.59
# Incremental cost:  47,698,591,937 IRR
# Incremental QALY:  1.92
# ICER: 24,875,936,637 IRR/QALY
#
# lifetime prophylaxis bayesian severe_arthropathy_utility_low vs lifetime on_demand bayesian severe_arthropathy_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,264,323,176,117 IRR
# Control cost:      266,582,207,987 IRR
# Intervention QALY: 55.81
# Control QALY:      25.93
# Incremental cost:  997,740,968,130 IRR
# Incremental QALY:  29.88
# ICER: 33,392,970,801 IRR/QALY
#
# early prophylaxis bayesian severe_arthropathy_utility_high vs early on_demand bayesian severe_arthropathy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,947,162,332 IRR
# Control cost:      27,089,124,483 IRR
# Intervention QALY: 8.51
# Control QALY:      6.59
# Incremental cost:  47,858,037,849 IRR
# Incremental QALY:  1.92
# ICER: 24,926,827,860 IRR/QALY
#
# lifetime prophylaxis bayesian severe_arthropathy_utility_high vs lifetime on_demand bayesian severe_arthropathy_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,230,109,646,452 IRR
# Control cost:      262,290,177,984 IRR
# Intervention QALY: 54.51
# Control QALY:      26.15
# Incremental cost:  967,819,468,468 IRR
# Incremental QALY:  28.35
# ICER: 34,136,126,340 IRR/QALY
#
# early prophylaxis bayesian spontaneous_bleeding_utility_low vs early on_demand bayesian spontaneous_bleeding_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,512,422,276 IRR
# Control cost:      27,151,870,849 IRR
# Intervention QALY: 8.55
# Control QALY:      6.54
# Incremental cost:  48,360,551,426 IRR
# Incremental QALY:  2.01
# ICER: 24,038,200,175 IRR/QALY
#
# lifetime prophylaxis bayesian spontaneous_bleeding_utility_low vs lifetime on_demand bayesian spontaneous_bleeding_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,256,537,556,462 IRR
# Control cost:      268,976,672,500 IRR
# Intervention QALY: 55.55
# Control QALY:      26.35
# Incremental cost:  987,560,883,962 IRR
# Incremental QALY:  29.21
# ICER: 33,812,636,962 IRR/QALY
#
# early prophylaxis bayesian spontaneous_bleeding_utility_high vs early on_demand bayesian spontaneous_bleeding_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,190,578,179 IRR
# Control cost:      27,692,625,956 IRR
# Intervention QALY: 8.54
# Control QALY:      6.70
# Incremental cost:  47,497,952,224 IRR
# Incremental QALY:  1.85
# ICER: 25,730,683,686 IRR/QALY
#
# lifetime prophylaxis bayesian spontaneous_bleeding_utility_high vs lifetime on_demand bayesian spontaneous_bleeding_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,230,743,284,432 IRR
# Control cost:      261,110,688,865 IRR
# Intervention QALY: 54.48
# Control QALY:      26.04
# Incremental cost:  969,632,595,567 IRR
# Incremental QALY:  28.44
# ICER: 34,089,037,125 IRR/QALY
#
# early prophylaxis bayesian joint_bleeding_utility_low vs early on_demand bayesian joint_bleeding_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,823,541,088 IRR
# Control cost:      27,578,977,247 IRR
# Intervention QALY: 8.48
# Control QALY:      6.54
# Incremental cost:  47,244,563,842 IRR
# Incremental QALY:  1.94
# ICER: 24,364,611,197 IRR/QALY
#
# lifetime prophylaxis bayesian joint_bleeding_utility_low vs lifetime on_demand bayesian joint_bleeding_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,241,041,113,312 IRR
# Control cost:      258,876,440,188 IRR
# Intervention QALY: 54.74
# Control QALY:      25.34
# Incremental cost:  982,164,673,124 IRR
# Incremental QALY:  29.40
# ICER: 33,402,934,290 IRR/QALY
#
# early prophylaxis bayesian joint_bleeding_utility_high vs early on_demand bayesian joint_bleeding_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,905,725,227 IRR
# Control cost:      28,244,519,260 IRR
# Intervention QALY: 8.54
# Control QALY:      6.84
# Incremental cost:  46,661,205,967 IRR
# Incremental QALY:  1.70
# ICER: 27,456,341,127 IRR/QALY
#
# lifetime prophylaxis bayesian joint_bleeding_utility_high vs lifetime on_demand bayesian joint_bleeding_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,229,005,248,721 IRR
# Control cost:      250,808,959,658 IRR
# Intervention QALY: 54.47
# Control QALY:      25.35
# Incremental cost:  978,196,289,063 IRR
# Incremental QALY:  29.12
# ICER: 33,590,616,843 IRR/QALY
#
# early prophylaxis bayesian life_threatening_bleeding_utility_low vs early on_demand bayesian life_threatening_bleeding_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,215,853,718 IRR
# Control cost:      27,678,888,470 IRR
# Intervention QALY: 8.53
# Control QALY:      6.67
# Incremental cost:  47,536,965,248 IRR
# Incremental QALY:  1.86
# ICER: 25,533,624,461 IRR/QALY
#
# lifetime prophylaxis bayesian life_threatening_bleeding_utility_low vs lifetime on_demand bayesian life_threatening_bleeding_utility_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,271,379,336,220 IRR
# Control cost:      266,186,765,530 IRR
# Intervention QALY: 56.12
# Control QALY:      26.34
# Incremental cost:  1,005,192,570,690 IRR
# Incremental QALY:  29.78
# ICER: 33,753,108,146 IRR/QALY
#
# early prophylaxis bayesian life_threatening_bleeding_utility_high vs early on_demand bayesian life_threatening_bleeding_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,584,899,653 IRR
# Control cost:      27,655,614,166 IRR
# Intervention QALY: 8.57
# Control QALY:      6.66
# Incremental cost:  47,929,285,487 IRR
# Incremental QALY:  1.90
# ICER: 25,206,579,126 IRR/QALY
#
# lifetime prophylaxis bayesian life_threatening_bleeding_utility_high vs lifetime on_demand bayesian life_threatening_bleeding_utility_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,261,172,799,812 IRR
# Control cost:      249,501,380,224 IRR
# Intervention QALY: 55.69
# Control QALY:      25.01
# Incremental cost:  1,011,671,419,588 IRR
# Incremental QALY:  30.69
# ICER: 32,968,827,959 IRR/QALY
#
# early prophylaxis bayesian prophylaxis_background_factor_consumption_per_kg_low vs early on_demand bayesian prophylaxis_background_factor_consumption_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 30,086,300,010 IRR
# Control cost:      27,686,284,630 IRR
# Intervention QALY: 8.51
# Control QALY:      6.64
# Incremental cost:  2,400,015,380 IRR
# Incremental QALY:  1.88
# ICER: 1,278,399,255 IRR/QALY
#
# lifetime prophylaxis bayesian prophylaxis_background_factor_consumption_per_kg_low vs lifetime on_demand bayesian prophylaxis_background_factor_consumption_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 523,090,013,858 IRR
# Control cost:      272,036,598,434 IRR
# Intervention QALY: 57.50
# Control QALY:      26.68
# Incremental cost:  251,053,415,424 IRR
# Incremental QALY:  30.82
# ICER: 8,146,246,912 IRR/QALY
#
# early prophylaxis bayesian prophylaxis_background_factor_consumption_per_kg_high vs early on_demand bayesian prophylaxis_background_factor_consumption_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 144,678,337,601 IRR
# Control cost:      27,384,491,536 IRR
# Intervention QALY: 8.57
# Control QALY:      6.62
# Incremental cost:  117,293,846,065 IRR
# Incremental QALY:  1.95
# ICER: 60,203,695,072 IRR/QALY
#
# lifetime prophylaxis bayesian prophylaxis_background_factor_consumption_per_kg_high vs lifetime on_demand bayesian prophylaxis_background_factor_consumption_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 2,439,041,206,911 IRR
# Control cost:      266,791,372,245 IRR
# Intervention QALY: 56.29
# Control QALY:      26.22
# Incremental cost:  2,172,249,834,666 IRR
# Incremental QALY:  30.07
# ICER: 72,240,498,095 IRR/QALY
#
# early prophylaxis bayesian factor_consumption_per_spontaneous_bleeding_per_kg_low vs early on_demand bayesian factor_consumption_per_spontaneous_bleeding_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 73,838,488,599 IRR
# Control cost:      24,687,907,206 IRR
# Intervention QALY: 8.45
# Control QALY:      6.56
# Incremental cost:  49,150,581,393 IRR
# Incremental QALY:  1.89
# ICER: 25,944,417,524 IRR/QALY
#
# lifetime prophylaxis bayesian factor_consumption_per_spontaneous_bleeding_per_kg_low vs lifetime on_demand bayesian factor_consumption_per_spontaneous_bleeding_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,275,858,313,304 IRR
# Control cost:      238,154,085,455 IRR
# Intervention QALY: 56.59
# Control QALY:      26.03
# Incremental cost:  1,037,704,227,850 IRR
# Incremental QALY:  30.56
# ICER: 33,951,280,232 IRR/QALY
#
# early prophylaxis bayesian factor_consumption_per_spontaneous_bleeding_per_kg_high vs early on_demand bayesian factor_consumption_per_spontaneous_bleeding_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,720,219,657 IRR
# Control cost:      30,652,769,498 IRR
# Intervention QALY: 8.53
# Control QALY:      6.67
# Incremental cost:  45,067,450,158 IRR
# Incremental QALY:  1.85
# ICER: 24,321,192,407 IRR/QALY
#
# lifetime prophylaxis bayesian factor_consumption_per_spontaneous_bleeding_per_kg_high vs lifetime on_demand bayesian factor_consumption_per_spontaneous_bleeding_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,262,766,075,101 IRR
# Control cost:      295,198,774,438 IRR
# Intervention QALY: 55.39
# Control QALY:      26.16
# Incremental cost:  967,567,300,663 IRR
# Incremental QALY:  29.22
# ICER: 33,109,439,964 IRR/QALY
#
# early prophylaxis bayesian factor_consumption_per_joint_bleeding_per_kg_low vs early on_demand bayesian factor_consumption_per_joint_bleeding_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 74,445,924,089 IRR
# Control cost:      24,035,658,822 IRR
# Intervention QALY: 8.54
# Control QALY:      6.69
# Incremental cost:  50,410,265,267 IRR
# Incremental QALY:  1.85
# ICER: 27,282,165,896 IRR/QALY
#
# lifetime prophylaxis bayesian factor_consumption_per_joint_bleeding_per_kg_low vs lifetime on_demand bayesian factor_consumption_per_joint_bleeding_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,285,971,054,421 IRR
# Control cost:      222,343,923,071 IRR
# Intervention QALY: 57.17
# Control QALY:      25.34
# Incremental cost:  1,063,627,131,350 IRR
# Incremental QALY:  31.83
# ICER: 33,416,155,338 IRR/QALY
#
# early prophylaxis bayesian factor_consumption_per_joint_bleeding_per_kg_high vs early on_demand bayesian factor_consumption_per_joint_bleeding_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,107,681,279 IRR
# Control cost:      31,308,948,146 IRR
# Intervention QALY: 8.45
# Control QALY:      6.53
# Incremental cost:  43,798,733,133 IRR
# Incremental QALY:  1.92
# ICER: 22,848,452,851 IRR/QALY
#
# lifetime prophylaxis bayesian factor_consumption_per_joint_bleeding_per_kg_high vs lifetime on_demand bayesian factor_consumption_per_joint_bleeding_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,300,088,763,321 IRR
# Control cost:      296,394,266,790 IRR
# Intervention QALY: 56.66
# Control QALY:      25.46
# Incremental cost:  1,003,694,496,531 IRR
# Incremental QALY:  31.20
# ICER: 32,169,057,037 IRR/QALY
#
# early prophylaxis bayesian factor_consumption_per_life_threatening_bleeding_per_kg_low vs early on_demand bayesian factor_consumption_per_life_threatening_bleeding_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,465,257,572 IRR
# Control cost:      26,111,277,445 IRR
# Intervention QALY: 8.58
# Control QALY:      6.59
# Incremental cost:  49,353,980,127 IRR
# Incremental QALY:  1.99
# ICER: 24,790,843,203 IRR/QALY
#
# lifetime prophylaxis bayesian factor_consumption_per_life_threatening_bleeding_per_kg_low vs lifetime on_demand bayesian factor_consumption_per_life_threatening_bleeding_per_kg_low
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,282,988,151,823 IRR
# Control cost:      245,084,410,992 IRR
# Intervention QALY: 56.78
# Control QALY:      25.47
# Incremental cost:  1,037,903,740,831 IRR
# Incremental QALY:  31.32
# ICER: 33,143,235,188 IRR/QALY
#
# early prophylaxis bayesian factor_consumption_per_life_threatening_bleeding_per_kg_high vs early on_demand bayesian factor_consumption_per_life_threatening_bleeding_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 75,595,067,948 IRR
# Control cost:      29,099,089,904 IRR
# Intervention QALY: 8.53
# Control QALY:      6.65
# Incremental cost:  46,495,978,044 IRR
# Incremental QALY:  1.88
# ICER: 24,752,381,658 IRR/QALY
#
# lifetime prophylaxis bayesian factor_consumption_per_life_threatening_bleeding_per_kg_high vs lifetime on_demand bayesian factor_consumption_per_life_threatening_bleeding_per_kg_high
# Intervention ABR: 4
# Control ABR: 23
# Intervention cost: 1,233,945,457,857 IRR
# Control cost:      276,513,887,578 IRR
# Intervention QALY: 54.41
# Control QALY:      25.96
# Incremental cost:  957,431,570,279 IRR
# Incremental QALY:  28.45
# ICER: 33,651,398,608 IRR/QALY

# %%
from typing import Literal

from app.notebook.scenario_helpers import (
    get_base_pair_key,
    get_parameter_label,
    split_tornado_extensions,
)
from app.notebook.storage import store
from app.visualization.plots import OWSAPlotter

base_early_pair = pairs[:1]
base_lifetime_pair = pairs[1:2]

p_low, p_high = split_tornado_extensions(pairs[2:])

base_pairs = base_early_pair + base_lifetime_pair
base_results: dict[tuple[str, str], dict[str, float]] = {}
owsa_rows = []


def get_incremental(df: pl.DataFrame, pair: tuple[str, str]) -> dict[str, float]:
    """returns incremental cost and QALY for the intervention vs control in the pair"""

    control, intervention = pair
    control_df = df.filter(pl.col("scenario") == control)
    intervention_df = df.filter(pl.col("scenario") == intervention)

    return {
        "incremental_cost": intervention_df["total_cost"].mean()
        - control_df["total_cost"].mean(),
        "incremental_qaly": intervention_df["total_qaly"].mean()
        - control_df["total_qaly"].mean(),
    }


def calculate_icer(df: pl.Series) -> float:
    """Calculate ICER from incremental cost and QALY in the given DataFrame row."""
    incremental_cost = df["incremental_cost"]
    incremental_qaly = df["incremental_qaly"]

    if incremental_qaly == 0:
        return np.inf  # Avoid division by zero; interpret as infinitely costly per QALY
    else:
        return incremental_cost / incremental_qaly


base_results = {
    get_base_pair_key(control): get_incremental(
        df,
        (control, intervention),
    )
    for control, intervention in base_pairs
}


class ErrorMessages:
    MISSING_BASE_RESULT = "No base result found for scenario pair with control '{}'"
    UNEXPECTED_SUFFIX = "Unexpected suffix '{}' in scenario '{}'"


for control, intervention in p_low + p_high:

    time_horizon, regime, sampling_method, extension = parse_scenario(control)
    parameter = get_parameter_label(extension)
    suffix: Literal["low", "high"] = extension.rsplit("_", 1)[-1]  # type: ignore

    if suffix not in {"low", "high"}:
        raise ValueError(ErrorMessages.UNEXPECTED_SUFFIX.format(suffix, control))

    baseline_key = get_base_pair_key(control)
    base = base_results.get(baseline_key)

    if base is None:
        raise ValueError(ErrorMessages.MISSING_BASE_RESULT.format(control))

    summary = get_incremental(df, (control, intervention))

    # ICER calculations
    base_icer = calculate_icer(base)
    scenario_icer = calculate_icer(summary)
    icer_diff_from_base = scenario_icer - base_icer

    owsa_rows.append(
        {
            "time_horizon": time_horizon,
            "sampling_method": sampling_method,
            "parameter": parameter,
            "scenario_type": suffix,
            "incremental_cost": summary["incremental_cost"],
            "incremental_qaly": summary["incremental_qaly"],
            "icer": scenario_icer,
            "base_incremental_cost": base["incremental_cost"],
            "base_incremental_qaly": base["incremental_qaly"],
            "base_icer": base_icer,
            "icer_diff_from_base": icer_diff_from_base,
        }
    )

owsa_df = pl.DataFrame(owsa_rows)

# Pivot summary
owsa_icer_summary = owsa_df.pivot_table(
    index=["time_horizon", "sampling_method", "parameter"],
    columns="scenario_type",
    values="icer_diff_from_base",
    aggfunc="first",
)# Rename columns
owsa_icer_summary = owsa_icer_summary.rename(
    columns={
        "low": "low_icer_change",
        "high": "high_icer_change",
    }
)

# Sensitivity magnitude
owsa_icer_summary["magnitude"] = (
    owsa_icer_summary[["low_icer_change", "high_icer_change"]].abs().max(axis=1)
)
print("OWSA ICER summary table, outputs/owsa_icer_summary.csv:")
store(owsa_icer_summary, root / "outputs" / "owsa_icer_summary.csv", override=False)
print(owsa_icer_summary.sort("magnitude", descending=True).head(20))
# Out:
# OWSA ICER summary table, outputs/owsa_icer_summary.csv:
# File 'C:\Users\Jino\Desktop\University\NOKI\markov-chain-3-14\outputs\owsa_icer_summary.csv' already exists. Set override=True to overwrite.
# scenario_type time_horizon sampling_method  \
# 0                    early        bayesian
# 14                lifetime        bayesian
# 25                lifetime        bayesian
# 11                   early        bayesian
# 4                    early        bayesian
# 21                lifetime        bayesian
# 9                    early        bayesian
# 7                    early        bayesian
# 23                lifetime        bayesian
# 18                lifetime        bayesian
# 1                    early        bayesian
# 6                    early        bayesian
# 5                    early        bayesian
# 13                   early        bayesian
# 10                   early        bayesian
# 26                lifetime        bayesian
# 27                lifetime        bayesian
# 3                    early        bayesian
# 19                lifetime        bayesian
# 17                lifetime        bayesian
#
# scenario_type                                          parameter  \
# 0                                                            abr
# 14                                                           abr
# 25              prophylaxis_background_factor_consumption_per_kg
# 11              prophylaxis_background_factor_consumption_per_kg
# 4                                                healthy_utility
# 21                            life_threatening_bleeding_fraction
# 9                                       mild_arthropathy_utility
# 7                             life_threatening_bleeding_fraction
# 23                                      mild_arthropathy_utility
# 18                                               healthy_utility
# 1                   factor_consumption_per_joint_bleeding_per_kg
# 6                                         joint_bleeding_utility
# 5                                        joint_bleeding_fraction
# 13                                  spontaneous_bleeding_utility
# 10                                  moderate_arthropathy_utility
# 26                                    severe_arthropathy_utility
# 27                                  spontaneous_bleeding_utility
# 3              factor_consumption_per_spontaneous_bleeding_pe...
# 19                                       joint_bleeding_fraction
# 17             factor_consumption_per_spontaneous_bleeding_pe...
#
# scenario_type  high_icer_change  low_icer_change     magnitude
# 0                 -1.890347e+10     1.273393e+11  1.273393e+11
# 14                -7.175899e+09     7.682663e+10  7.682663e+10
# 25                 3.924769e+10    -2.484656e+10  3.924769e+10
# 11                 3.483706e+10    -2.408823e+10  3.483706e+10
# 4                 -5.640348e+09     1.034873e+10  1.034873e+10
# 21                -3.671626e+09     5.956796e+09  5.956796e+09
# 9                  4.224854e+09    -3.952674e+09  4.224854e+09
# 7                 -3.815180e+09     1.819345e+09  3.815180e+09
# 23                -2.146641e+09     3.793152e+09  3.793152e+09
# 18                -5.067291e+08     2.702009e+09  2.702009e+09
# 1                 -2.518178e+09     1.915535e+09  2.518178e+09
# 6                  2.089710e+09    -1.002020e+09  2.089710e+09
# 5                 -2.105262e+08    -1.344038e+09  1.344038e+09
# 13                 3.640527e+08    -1.328431e+09  1.328431e+09
# 10                 2.932902e+07     1.235499e+09  1.235499e+09
# 26                 1.143318e+09     4.001628e+08  1.143318e+09
# 27                 1.096229e+09     8.198290e+08  1.096229e+09
# 3                 -1.045439e+09     5.777866e+08  1.045439e+09
# 19                 4.103489e+08     1.029924e+09  1.029924e+09
# 17                 1.166320e+08     9.584723e+08  9.584723e+08

# %%
print("\n=== ICER Tornado Diagram (Dual Bars Style) ===")

OWSAPlotter.plot_owsa_icer_tornado(
    owsa_icer_summary,
    filter_horizon="early",
    style="dual_bars",
)

OWSAPlotter.plot_owsa_icer_tornado(
    owsa_icer_summary,
    filter_horizon="lifetime",
    style="dual_bars",
)
# Out:
# === ICER Tornado Diagram (Dual Bars Style) ===

# %%
# Plot using error bars (compact ICER style)
print("\n=== ICER Tornado Diagram (Errorbar Style - Compact) ===")
OWSAPlotter.plot_owsa_icer_tornado(
    owsa_icer_summary, filter_horizon="early", style="errorbar"
)
OWSAPlotter.plot_owsa_icer_tornado(
    owsa_icer_summary, filter_horizon="lifetime", style="errorbar"
)
# Out:
# === ICER Tornado Diagram (Errorbar Style - Compact) ===

# %%
# ============================================================
# ICER RESULTS INTERPRETATION & ONE-WAY SENSITIVITY ANALYSIS
# ============================================================

print("\n" + "=" * 90)
print("BASE-CASE COST-EFFECTIVENESS RESULTS")
print("=" * 90)

# -----------------------------
# Base-case ICER computation
# -----------------------------
baseline_table = []

for (time_horizon, sampling_method), results in base_results.items():

    delta_cost = results["incremental_cost"]
    delta_qaly = results["incremental_qaly"]

    base_icer = delta_cost / delta_qaly if delta_qaly != 0 else float("inf")

    baseline_table.append(
        {
            "Time Horizon": time_horizon,
            "Sampling Method": sampling_method,
            "Incremental Cost (IRR)": f"{delta_cost:,.0f}",
            "Incremental QALY": f"{delta_qaly:.4f}",
            "ICER (IRR/QALY)": (
                f"{base_icer:,.0f}" if base_icer != float("inf") else "Undefined"
            ),
        }
    )

baseline_df = pl.DataFrame(baseline_table)

print("\nBase-case results (Prophylaxis vs On-Demand):")
print(baseline_df)


# ============================================================
# ONE-WAY SENSITIVITY ANALYSIS (OWSA) — ICER TORNADO RANKING
# ============================================================

print("\n" + "=" * 90)
print("ONE-WAY SENSITIVITY ANALYSIS (ICER TORNADO RANKING)")
print("=" * 90)

for horizon in ["early", "lifetime"]:

    print("\n-----------------------------")
    print(f"TIME HORIZON: {horizon.upper()}")
    print("-----------------------------\n")

    subset = owsa_icer_summary.filter(pl.col("time_horizon") == horizon)

    if subset.is_empty():
        print("No OWSA results available for this time horizon.")
        continue

    # Sensitivity metric: maximum absolute deviation from base ICER
    subset["sensitivity"] = (
        subset[["low_icer_change", "high_icer_change"]].abs().max(axis=1)
    )

    subset = subset.sort("sensitivity", descending=True)

    summary_table = []

    for row in subset.iter_rows(named=True):

        summary_table.append(
            {
                "Parameter": row["parameter"],
                "ICER (Low Scenario)": f"{row['low_icer_change']:,.0f}",
                "ICER (High Scenario)": f"{row['high_icer_change']:,.0f}",
                "Absolute Range": f"{abs(row['high_icer_change'] - row['low_icer_change']):,.0f}",
                "Max Sensitivity": f"{row['sensitivity']:,.0f}",
            }
        )

    summary_df = pl.DataFrame(summary_table)

    print("Deterministic OWSA results ranked by ICER sensitivity:")
    print(summary_df)


# ============================================================
# ROBUSTNESS EVALUATION AGAINST COST-EFFECTIVENESS THRESHOLD
# ============================================================

print("\n" + "=" * 90)
print("COST-EFFECTIVENESS ROBUSTNESS ANALYSIS")
print("=" * 90)

gdp_per_capita = context.economic_policy.gdp_per_capita.IRR
disease_wtp_ratio = context.economic_policy.wtp_multiplier.rare
WTP = gdp_per_capita * disease_wtp_ratio
ce_threshold = WTP  # IRR per QALY

print(f"\nWillingness-to-pay threshold: {ce_threshold:,.0f} IRR/QALY")

for horizon in ["early", "lifetime"]:

    key = (horizon, "bayesian")

    if key not in base_results:
        continue

    result = base_results[key]

    base_cost = result["incremental_cost"]
    base_qaly = result["incremental_qaly"]

    base_icer = base_cost / base_qaly if base_qaly != 0 else float("inf")

    print("\n-----------------------------")
    print(f"{horizon.upper()} HORIZON")
    print("-----------------------------")

    print(f"Base-case ICER: {base_icer:,.0f} IRR/QALY")

    base_ce = base_icer < ce_threshold
    print(
        f"Cost-effectiveness status: {'Cost-effective' if base_ce else 'Not cost-effective'}"
    )

    owsa_subset = owsa_icer_summary.filter(pl.col("time_horizon") == horizon)

    if not owsa_subset.is_empty():

        max_dev = owsa_subset[["low_icer_change", "high_icer_change"]].abs().max().max()

        worst_case = base_icer + max_dev
        best_case = base_icer - max_dev

        print("\nOWSA impact on ICER:")
        print(f"Maximum parameter-driven deviation: ±{max_dev:,.0f} IRR/QALY")

        print(
            f"ICER range (best–worst case): {best_case:,.0f} – {worst_case:,.0f} IRR/QALY"
        )

        worst_ce = worst_case < ce_threshold
        best_ce = best_case < ce_threshold

        if base_ce == worst_ce == best_ce:
            print("Conclusion: Robust cost-effectiveness across parameter uncertainty.")
        else:
            print(
                "Conclusion: Cost-effectiveness is sensitive to parameter uncertainty."
            )

            if base_ce and not worst_ce:
                print(
                    "Risk: May become not cost-effective under pessimistic assumptions."
                )
            elif not base_ce and best_ce:
                print(
                    "Opportunity: May become cost-effective under optimistic assumptions."
                )
# Out:
# ==========================================================================================
# BASE-CASE COST-EFFECTIVENESS RESULTS
# ==========================================================================================
#
# Base-case results (Prophylaxis vs On-Demand):
# Time Horizon Sampling Method Incremental Cost (IRR) Incremental QALY ICER (IRR/QALY)
#        early        bayesian         47,444,858,716           1.8704  25,366,630,960
#     lifetime        bayesian      1,049,524,529,180          31.8107  32,992,807,974
#
# ==========================================================================================
# ONE-WAY SENSITIVITY ANALYSIS (ICER TORNADO RANKING)
# ==========================================================================================
#
# -----------------------------
# TIME HORIZON: EARLY
# -----------------------------
#
# Deterministic OWSA results ranked by ICER sensitivity:
#                                               Parameter ICER (Low Scenario) ICER (High Scenario)  Absolute Range Max Sensitivity
#                                                     abr     127,339,303,427      -18,903,465,812 146,242,769,239 127,339,303,427
#        prophylaxis_background_factor_consumption_per_kg     -24,088,231,705       34,837,064,111  58,925,295,816  34,837,064,111
#                                         healthy_utility      10,348,732,606       -5,640,348,071  15,989,080,677  10,348,732,606
#                                mild_arthropathy_utility      -3,952,673,918        4,224,854,412   8,177,528,330   4,224,854,412
#                      life_threatening_bleeding_fraction       1,819,345,442       -3,815,179,909   5,634,525,351   3,815,179,909
#            factor_consumption_per_joint_bleeding_per_kg       1,915,534,936       -2,518,178,109   4,433,713,045   2,518,178,109
#                                  joint_bleeding_utility      -1,002,019,763        2,089,710,167   3,091,729,930   2,089,710,167
#                                 joint_bleeding_fraction      -1,344,037,917         -210,526,195   1,133,511,722   1,344,037,917
#                            spontaneous_bleeding_utility      -1,328,430,785          364,052,726   1,692,483,511   1,328,430,785
#                            moderate_arthropathy_utility       1,235,499,432           29,329,022   1,206,170,410   1,235,499,432
#      factor_consumption_per_spontaneous_bleeding_per_kg         577,786,563       -1,045,438,554   1,623,225,117   1,045,438,554
# factor_consumption_per_life_threatening_bleeding_per_kg        -575,787,757         -614,249,302      38,461,544     614,249,302
#                              severe_arthropathy_utility        -490,694,323         -439,803,101      50,891,223     490,694,323
#                       life_threatening_bleeding_utility         166,993,501         -160,051,834     327,045,335     166,993,501
#
# -----------------------------
# TIME HORIZON: LIFETIME
# -----------------------------
#
# Deterministic OWSA results ranked by ICER sensitivity:
#                                               Parameter ICER (Low Scenario) ICER (High Scenario) Absolute Range Max Sensitivity
#                                                     abr      76,826,631,112       -7,175,899,398 84,002,530,510  76,826,631,112
#        prophylaxis_background_factor_consumption_per_kg     -24,846,561,062       39,247,690,121 64,094,251,183  39,247,690,121
#                      life_threatening_bleeding_fraction       5,956,796,222       -3,671,626,103  9,628,422,325   5,956,796,222
#                                mild_arthropathy_utility       3,793,152,048       -2,146,641,228  5,939,793,276   3,793,152,048
#                                         healthy_utility       2,702,008,631         -506,729,085  3,208,737,716   2,702,008,631
#                              severe_arthropathy_utility         400,162,827        1,143,318,365    743,155,539   1,143,318,365
#                            spontaneous_bleeding_utility         819,828,988        1,096,229,150    276,400,162   1,096,229,150
#                                 joint_bleeding_fraction       1,029,923,949          410,348,861    619,575,087   1,029,923,949
#      factor_consumption_per_spontaneous_bleeding_per_kg         958,472,258          116,631,990    841,840,268     958,472,258
#                            moderate_arthropathy_utility         909,336,006          852,243,994     57,092,012     909,336,006
#            factor_consumption_per_joint_bleeding_per_kg         423,347,363         -823,750,937  1,247,098,301     823,750,937
#                       life_threatening_bleeding_utility         760,300,171          -23,980,015    784,280,186     760,300,171
# factor_consumption_per_life_threatening_bleeding_per_kg         150,427,213          658,590,634    508,163,420     658,590,634
#                                  joint_bleeding_utility         410,126,315          597,808,869    187,682,554     597,808,869
#
# ==========================================================================================
# COST-EFFECTIVENESS ROBUSTNESS ANALYSIS
# ==========================================================================================
#
# Willingness-to-pay threshold: 18,000,000,000 IRR/QALY
#
# -----------------------------
# EARLY HORIZON
# -----------------------------
# Base-case ICER: 25,366,630,960 IRR/QALY
# Cost-effectiveness status: Not cost-effective
#
# OWSA impact on ICER:
# Maximum parameter-driven deviation: ±127,339,303,427 IRR/QALY
# ICER range (best–worst case): -101,972,672,467 – 152,705,934,388 IRR/QALY
# Conclusion: Cost-effectiveness is sensitive to parameter uncertainty.
# Opportunity: May become cost-effective under optimistic assumptions.
#
# -----------------------------
# LIFETIME HORIZON
# -----------------------------
# Base-case ICER: 32,992,807,974 IRR/QALY
# Cost-effectiveness status: Not cost-effective
#
# OWSA impact on ICER:
# Maximum parameter-driven deviation: ±76,826,631,112 IRR/QALY
# ICER range (best–worst case): -43,833,823,138 – 109,819,439,086 IRR/QALY
# Conclusion: Cost-effectiveness is sensitive to parameter uncertainty.
# Opportunity: May become cost-effective under optimistic assumptions.
