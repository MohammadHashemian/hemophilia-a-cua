# %% [markdown]
# # Childhood OWSA simulation | ages 1-15
#
# Runs the composable OWSA workflow. Inputs are fixed at base/low/high point values. The default 1,000 replications estimate microsimulation noise and are not PSA draws. Common random numbers are used across scenarios.

# %%
from app.notebook.owsa.workflow import DEFAULT_OWSA_REPLICATIONS, run_horizon
from app.notebook.psa import CHILDHOOD

print(f"OWSA microsimulation replications per scenario: {DEFAULT_OWSA_REPLICATIONS:,}")
results_path = run_horizon(CHILDHOOD, replications=DEFAULT_OWSA_REPLICATIONS)
print(results_path)
# Out:
# OWSA microsimulation replications per scenario: 1,000
# [22:14:42] INFO     OWSA design: 94 deterministic scenarios, 1000 stochastic replications per scenario, common random numbers enabled
# [22:14:42] INFO     Starting batch runner with 94 scenario, batch size: 4, engine: batch
# [22:14:42] INFO     Reusing scenario cache for childhood on-demand bayesian
# [22:14:43] INFO     Reusing scenario cache for childhood prophylaxis bayesian
# [22:14:43] INFO     Reusing scenario cache for childhood on-demand bayesian joint_bleeding_fraction_low
# [22:14:43] INFO     Reusing scenario cache for childhood prophylaxis bayesian joint_bleeding_fraction_low
# [22:14:43] INFO     Reusing scenario cache for childhood on-demand bayesian joint_bleeding_fraction_high
# [22:14:43] INFO     Reusing scenario cache for childhood prophylaxis bayesian joint_bleeding_fraction_high
# [22:14:43] INFO     Reusing scenario cache for childhood on-demand bayesian gi_neck_bleeding_fraction_low
# ...

# %%
import polars as pl

from app.notebook.owsa.workflow import load_horizon_results

df = load_horizon_results(CHILDHOOD)
assert df['time_horizon'].unique().to_list() == [CHILDHOOD.key]
assert df['cycles'].unique().to_list() == [CHILDHOOD.cycles]

grouped = df.group_by(['regime', 'extension']).len().sort(['extension', 'regime'])
with pl.Config(tbl_rows=-1, tbl_cols=-1, tbl_width_chars=1000, fmt_str_lengths=200):
    display(grouped)
# Out:
# shape: (94, 3)
# ┌─────────────┬────────────────────────────────────────────────────────────┬──────┐
# │ regime      ┆ extension                                                  ┆ len  │
# │ ---         ┆ ---                                                        ┆ ---  │
# │ str         ┆ str                                                        ┆ u32  │
# ╞═════════════╪════════════════════════════════════════════════════════════╪══════╡
# │ on-demand   ┆ null                                                       ┆ 1000 │
# │ prophylaxis ┆ null                                                       ┆ 1000 │
# │ on-demand   ┆ advanced_arthropathy_utility_high                          ┆ 1000 │
# │ prophylaxis ┆ advanced_arthropathy_utility_high                          ┆ 1000 │
# │ on-demand   ┆ advanced_arthropathy_utility_low                           ┆ 1000 │
# │ prophylaxis ┆ advanced_arthropathy_utility_low                           ┆ 1000 │
# ...
