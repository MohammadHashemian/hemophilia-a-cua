# %% [markdown]
# # Childhood PSA simulation
#
# Runs only the childhood horizon (ages 1–15) and writes to its dedicated cache.

# %%
from app.notebook.psa import CHILDHOOD
from app.notebook.psa.workflow import run_horizon

results_path = run_horizon(CHILDHOOD)
results_path
# Out:
# [12:19:14] INFO     Starting batch runner with 16 scenario, batch size: 4, engine: batch
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood on-demand bayesian | 10000 iters 100%|| 10000/10000 [00:56&lt;00:00, 177.85 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood prophylaxis bayesian | 10000 iters 100%|| 10000/10000 [00:56&lt;00:00, 178.73 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood on-demand dirichlet | 10000 iters 100%|| 10000/10000 [00:58&lt;00:00, 173.60 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood prophylaxis dirichlet | 10000 iters 100%|| 10000/10000 [00:53&lt;00:00, 188.71 iter/s]</pre>
#   </div>
# </div>
# [12:23:09] INFO     Saved temp batch 0 to C:\Users\Jino\Desktop\University\hemophilia\markov-chain-3-14\app\cache\psa\childhood_age_1_15\temp\parquet_temp\batch_0.parquet
# [12:23:09] INFO     Batch 1/4 complete (4 scenarios processed, 12 remaining). Elapsed=235.3s, avg_batch=235.3s, est_remaining=705.8s
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood on-demand bayesian ich_pooled | 10000 iters 100%|| 10000/10000 [00:49&lt;00:00, 203.41 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood prophylaxis bayesian ich_pooled | 10000 iters 100%|| 10000/10000 [00:51&lt;00:00, 197.13 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood on-demand dirichlet ich_pooled | 10000 iters 100%|| 10000/10000 [00:55&lt;00:00, 182.29 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood prophylaxis dirichlet ich_pooled | 10000 iters 100%|| 10000/10000 [00:49&lt;00:00, 204.86 iter/s]</pre>
#   </div>
# </div>
# [12:26:48] INFO     Saved temp batch 1 to C:\Users\Jino\Desktop\University\hemophilia\markov-chain-3-14\app\cache\psa\childhood_age_1_15\temp\parquet_temp\batch_1.parquet
# [12:26:48] INFO     Batch 2/4 complete (8 scenarios processed, 8 remaining). Elapsed=454.0s, avg_batch=227.0s, est_remaining=454.0s
# <style>
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood on-demand bayesian is_discounting | 10000 iters 100%|| 10000/10000 [00:51&lt;00:00, 196.09 iter/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>Batch Simulation | childhood prophylaxis bayesian is_discounting | 10000 iters  29%||  2856/10000 [00:13&lt;00:33, 216.35 iter/s]</pre>
#   </div>
# </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from app.notebook.psa import CHILDHOOD
#       2 from app.notebook.psa.workflow import run_horizon
#       3
# ----> 4 results_path = run_horizon(CHILDHOOD)
#       5 results_path
#
# File ~\Desktop\University\hemophilia\markov-chain-3-14\app\notebook\psa\workflow.py:128, in run_horizon(horizon, sample_size, batch_size)
#     121 bundles = build_bundles(
#     122     scenarios,
#     123     base_params,
#     124     context,
#     125     sample_size=sample_size,
#     126 )
#     127 cache_dir = horizon_cache_dir(root, spec)
# --> 128 run_scenarios_in_batches(
#     129     bundles=bundles,
#     130     context=context,
#     131     batch_size=batch_size,
#     132     engine="batch",
#     133     worker_function=worker_function,
#     134     identity_chain=identity_chain(),
#     135     output_dir=cache_dir / "parquet",
#     136     temp_dir=cache_dir / "temp" / "parquet_temp",
#     137     batch_worker_function=worker_function_batch,
#     138 )
#     139 path = horizon_results_path(root, spec)
#     140 logger.info("Completed %s PSA: %s", spec.label, path)
#
# File ~\Desktop\University\hemophilia\markov-chain-3-14\app\notebook\scenario_runner.py:316, in run_scenarios_in_batches(bundles, context, identity_chain, worker_function, batch_size, output_dir, temp_dir, options, engine, batch_worker_function)
#     314 for index, batch in enumerate(batch_generator(bundles, batch_size)):
#     315     if engine == "batch":
# --> 316         batch_results = _run_batch(
#     317             batch=batch,
#     318             context=context,
#     319             identity_chain=identity_chain,
#     320             batch_worker_function=batch_worker_function or worker_function,
#     321         )
#     322     else:
#     323         runner = ScenarioRunner(
#     324             context=context,
#     325             scenario_bundles=batch,
#    (...)    328             backend=engine,
#     329         )
#
# File ~\Desktop\University\hemophilia\markov-chain-3-14\app\notebook\scenario_runner.py:100, in _run_batch(batch, context, identity_chain, batch_worker_function)
#      97 def _on_step(step: int, total_steps: int) -> None:
#      98     progress.update(iters_per_year_tick)
# --> 100 outputs = batch_worker_function(
#     101     chain=identity_chain,
#     102     inputs=inputs,
#     103     scenario=scenario,
#     104     context=context,
#     105     run_id=run_id,
#     106     worker_id=worker_id,
#     107     progress_callback=_on_step,
#     108     progress_every=52,
#     109 )
#     110 # Integer-division rounding can leave a few iters unreported
#     111 # (e.g. 10000 iters / 98 years = 102 per year, 98 * 102 = 9996).
#     112 # Force the bar to 100% so the ETA settles cleanly.
#     113 remaining = n_iters - progress.count
#
# File ~\Desktop\University\hemophilia\markov-chain-3-14\app\domain\worker.py:401, in worker_function_batch(chain, inputs, scenario, context, run_id, worker_id, progress_callback, progress_every)
#     397 rng = np.random.default_rng(
#     398     context.simulation.environment.seed + worker_id
#     399 )
#     400 entrance_idx = states.index("healthy") if "healthy" in states else 0
# --> 401 batch_result = batch_chain.walk_batch(
#     402     steps=steps,
#     403     entrance_idx=entrance_idx,
#     404     rng=rng,
#     405     store_funcs=VECTORIZED_STORE_FUNCS,
#     406     reward_funcs=VECTORIZED_REWARD_FUNCS,
#     407     shared_kwargs=shared_kwargs,
#     408     progress_callback=progress_callback,
#     409     progress_every=progress_every,
#     410 )
#     412 # 5. Aggregate per-iter outputs
#     413 outputs = [
#     414     _aggregate_vectorized_output(inputs, batch_result, states, scenario.regime, i)
#     415     for i in range(len(inputs))
#     416 ]
#
# File ~\Desktop\University\hemophilia\markov-chain-3-14\engine\vectorized.py:290, in BatchMarkovChain.walk_batch(self, steps, entrance_idx, rng, store_funcs, reward_funcs, shared_kwargs, progress_callback, progress_every)
#     288 # Run store functions
#     289 for name, func in store_funcs.items():
# --> 290     out = func(
#     291         step=step,
#     292         state_idx=current_state_idx,
#     293         store_arrays=store_arrays,
#     294         shared_kwargs=shared_kwargs,
#     295         rng=rng,
#     296     )
#     297     store_arrays[name] = out
#     298     rewards[name][:, step] = out
#
# File ~\Desktop\University\hemophilia\markov-chain-3-14\app\domain\rewards\vectorized.py:124, in store_event_count(step, state_idx, store_arrays, shared_kwargs, rng)
#     122 # Sample: searchsorted on cumsum
#     123 cumsum = np.cumsum(probs)
# --> 124 idx = int(np.searchsorted(cumsum, u[i]))
#     125 if idx >= km:
#     126     idx = km - 1
#
# File c:\Users\Jino\miniconda3\envs\markov\Lib\site-packages\numpy\_core\fromnumeric.py:1501, in searchsorted(a, v, side, sorter)
#    1421 @array_function_dispatch(_searchsorted_dispatcher)
#    1422 def searchsorted(a, v, side='left', sorter=None):
#    1423     """
#    1424     Find indices where elements should be inserted to maintain order.
#    1425
#    (...)   1499     30  # The element at index 2 of the sorted array is 30.
#    1500     """
# -> 1501     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File c:\Users\Jino\miniconda3\envs\markov\Lib\site-packages\numpy\_core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      51     return _wrapit(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#      63     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
import polars as pl
from app.notebook.psa import CHILDHOOD
from app.notebook.psa.workflow import load_horizon_results

df = load_horizon_results(CHILDHOOD)
assert df["time_horizon"].unique().to_list() == [CHILDHOOD.key]
assert df["cycles"].unique().to_list() == [CHILDHOOD.cycles]
assert (
    df.group_by("scenario")
    .agg(pl.col("iteration_id").n_unique())
    .select(pl.col("iteration_id").min())
    .item()
    == df.group_by("scenario").len()["len"].min()
)
grouped_scenarios = (
    df.group_by(["sampling_method", "regime", "extension"])
    .len()
    .sort(["sampling_method", "regime", "extension"])
)

with pl.Config(tbl_rows=-1, tbl_cols=-1, tbl_width_chars=1000, fmt_str_lengths=200):
    display(grouped_scenarios)
# Out:
# shape: (16, 4)
# ┌─────────────────┬─────────────┬─────────────────────┬───────┐
# │ sampling_method ┆ regime      ┆ extension           ┆ len   │
# │ ---             ┆ ---         ┆ ---                 ┆ ---   │
# │ str             ┆ str         ┆ str                 ┆ u32   │
# ╞═════════════════╪═════════════╪═════════════════════╪═══════╡
# │ bayesian        ┆ on-demand   ┆ null                ┆ 10000 │
# │ bayesian        ┆ on-demand   ┆ is_discounting      ┆ 10000 │
# │ bayesian        ┆ on-demand   ┆ ltb_absolute        ┆ 10000 │
# │ bayesian        ┆ on-demand   ┆ weight_reduction_10 ┆ 10000 │
# │ bayesian        ┆ on-demand   ┆ weight_reduction_20 ┆ 10000 │
# │ bayesian        ┆ on-demand   ┆ weight_reduction_30 ┆ 10000 │
# │ bayesian        ┆ prophylaxis ┆ null                ┆ 10000 │
# │ bayesian        ┆ prophylaxis ┆ is_discounting      ┆ 10000 │
# │ bayesian        ┆ prophylaxis ┆ ltb_absolute        ┆ 10000 │
# │ bayesian        ┆ prophylaxis ┆ weight_reduction_10 ┆ 10000 │
# │ bayesian        ┆ prophylaxis ┆ weight_reduction_20 ┆ 10000 │
# │ bayesian        ┆ prophylaxis ┆ weight_reduction_30 ┆ 10000 │
# │ dirichlet       ┆ on-demand   ┆ null                ┆ 10000 │
# │ dirichlet       ┆ on-demand   ┆ ltb_absolute        ┆ 10000 │
# │ dirichlet       ┆ prophylaxis ┆ null                ┆ 10000 │
# │ dirichlet       ┆ prophylaxis ┆ ltb_absolute        ┆ 10000 │
# └─────────────────┴─────────────┴─────────────────────┴───────┘
